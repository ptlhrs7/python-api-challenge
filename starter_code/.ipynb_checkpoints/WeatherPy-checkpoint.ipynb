# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 591

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Lists and counters
city_list = []
cloud_list = []
country_list = []
date_list = []
humidity_list = []
lats_list = []
lngs_list = []
temp_max_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

print("Beginning Data Retrieval ")
print("-------------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

#For loop matching city names with city_list
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_list.append(response["name"])
        cloud_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lats_list.append(response["coord"]["lat"])
        lngs_list.append(response["coord"]["lon"])
        temp_max_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        
        else:
            index_counter = index_counter + 1
        
        print(f"Processing Record {index_counter} of Set {set_counter} | {city}")
        
    except(KeyError, IndexError):
        print("City not found. Skipping...")
        
print("-------------------------------")
print("Data Retrieval Complete")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | bengkulu
# Processing Record 3 of Set 1 | kualakapuas
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | tuatapere
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | kenai
# Processing Record 8 of Set 1 | sao filipe
# Processing Record 9 of Set 1 | iqaluit
# Processing Record 10 of Set 1 | vaini
# City not found. Skipping...
# Processing Record 11 of Set 1 | hasaki
# Processing Record 12 of Set 1 | itarema
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | cukai
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | kapaa
# City not found. Skipping...
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | salaga
# Processing Record 21 of Set 1 | tessalit
# Processing Record 22 of Set 1 | chara
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | severodvinsk
# Processing Record 25 of Set 1 | nanortalik
# Processing Record 26 of Set 1 | sisimiut
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | tagusao
# Processing Record 29 of Set 1 | dana point
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | lazaro cardenas
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | belmonte
# Processing Record 34 of Set 1 | tabuk
# Processing Record 35 of Set 1 | ayan
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | ulladulla
# Processing Record 38 of Set 1 | souillac
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | axim
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | goderich
# Processing Record 43 of Set 1 | tlacotepec
# Processing Record 44 of Set 1 | gizo
# City not found. Skipping...
# Processing Record 45 of Set 1 | alexander city
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | listvyanka
# Processing Record 48 of Set 1 | san patricio
# Processing Record 49 of Set 1 | santa isabel do rio negro
# Processing Record 50 of Set 1 | bethel
# Processing Record 0 of Set 2 | novikovo
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | garden city
# Processing Record 3 of Set 2 | trinidad
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | ararangua
# Processing Record 6 of Set 2 | najran
# Processing Record 7 of Set 2 | talnakh
# City not found. Skipping...
# Processing Record 8 of Set 2 | hargeysa
# Processing Record 9 of Set 2 | loreto
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | ossora
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | geraldton
# Processing Record 16 of Set 2 | gamba
# Processing Record 17 of Set 2 | kalabo
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 20 of Set 2 | hilo
# City not found. Skipping...
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | buin
# Processing Record 23 of Set 2 | thompson
# Processing Record 24 of Set 2 | la ronge
# Processing Record 25 of Set 2 | bastia
# Processing Record 26 of Set 2 | norman wells
# City not found. Skipping...
# Processing Record 27 of Set 2 | mitu
# Processing Record 28 of Set 2 | los llanos de aridane
# Processing Record 29 of Set 2 | kutum
# Processing Record 30 of Set 2 | quatre cocos
# City not found. Skipping...
# Processing Record 31 of Set 2 | makakilo city
# Processing Record 32 of Set 2 | tomatlan
# Processing Record 33 of Set 2 | cabo san lucas
# Processing Record 34 of Set 2 | lao cai
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | pimentel
# Processing Record 38 of Set 2 | rorvik
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | kalmar
# City not found. Skipping...
# Processing Record 41 of Set 2 | chifeng
# Processing Record 42 of Set 2 | kavieng
# Processing Record 43 of Set 2 | guerrero negro
# Processing Record 44 of Set 2 | kodiak
# Processing Record 45 of Set 2 | alofi
# Processing Record 46 of Set 2 | leningradskiy
# Processing Record 47 of Set 2 | dalvik
# Processing Record 48 of Set 2 | katsuura
# Processing Record 49 of Set 2 | hami
# Processing Record 50 of Set 2 | sur
# Processing Record 0 of Set 3 | lagoa
# Processing Record 1 of Set 3 | shaunavon
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | nikolskoye
# Processing Record 4 of Set 3 | adrar
# Processing Record 5 of Set 3 | vardo
# Processing Record 6 of Set 3 | meulaboh
# Processing Record 7 of Set 3 | sulangan
# Processing Record 8 of Set 3 | cristobal obregon
# City not found. Skipping...
# Processing Record 9 of Set 3 | mataura
# Processing Record 10 of Set 3 | kaitangata
# Processing Record 11 of Set 3 | tilichiki
# Processing Record 12 of Set 3 | jasper
# Processing Record 13 of Set 3 | tiksi
# Processing Record 14 of Set 3 | korla
# Processing Record 15 of Set 3 | saldanha
# Processing Record 16 of Set 3 | ust-kuyga
# Processing Record 17 of Set 3 | luau
# City not found. Skipping...
# Processing Record 18 of Set 3 | takoradi
# Processing Record 19 of Set 3 | ancud
# Processing Record 20 of Set 3 | kirkwood
# Processing Record 21 of Set 3 | garowe
# Processing Record 22 of Set 3 | longyearbyen
# City not found. Skipping...
# Processing Record 23 of Set 3 | college
# Processing Record 24 of Set 3 | merrill
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | ishigaki
# Processing Record 27 of Set 3 | kichera
# Processing Record 28 of Set 3 | chuy
# Processing Record 29 of Set 3 | plettenberg bay
# City not found. Skipping...
# Processing Record 30 of Set 3 | ratnagiri
# Processing Record 31 of Set 3 | three hills
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | hithadhoo
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | kungurtug
# Processing Record 36 of Set 3 | oistins
# City not found. Skipping...
# Processing Record 37 of Set 3 | pitimbu
# Processing Record 38 of Set 3 | misratah
# City not found. Skipping...
# Processing Record 39 of Set 3 | duldurga
# Processing Record 40 of Set 3 | pingliang
# Processing Record 41 of Set 3 | moose factory
# Processing Record 42 of Set 3 | touros
# Processing Record 43 of Set 3 | provideniya
# Processing Record 44 of Set 3 | teguldet
# Processing Record 45 of Set 3 | ugoofaaru
# Processing Record 46 of Set 3 | coquimbo
# Processing Record 47 of Set 3 | klaksvik
# Processing Record 48 of Set 3 | sola
# Processing Record 49 of Set 3 | muros
# Processing Record 50 of Set 3 | yerbogachen
# Processing Record 0 of Set 4 | erzin
# Processing Record 1 of Set 4 | conceicao do araguaia
# Processing Record 2 of Set 4 | lebu
# Processing Record 3 of Set 4 | lompoc
# City not found. Skipping...
# Processing Record 4 of Set 4 | hualmay
# Processing Record 5 of Set 4 | prince rupert
# Processing Record 6 of Set 4 | honggang
# Processing Record 7 of Set 4 | pangoa
# Processing Record 8 of Set 4 | maracai
# City not found. Skipping...
# Processing Record 9 of Set 4 | cururupu
# Processing Record 10 of Set 4 | aktau
# Processing Record 11 of Set 4 | dunedin
# Processing Record 12 of Set 4 | havelock
# Processing Record 13 of Set 4 | mezhdurechensk
# Processing Record 14 of Set 4 | cidreira
# Processing Record 15 of Set 4 | ribeira grande
# Processing Record 16 of Set 4 | fortuna foothills
# Processing Record 17 of Set 4 | esperance
# Processing Record 18 of Set 4 | north myrtle beach
# Processing Record 19 of Set 4 | saskylakh
# Processing Record 20 of Set 4 | ternate
# Processing Record 21 of Set 4 | svetlogorsk
# Processing Record 22 of Set 4 | lavrentiya
# Processing Record 23 of Set 4 | chapais
# Processing Record 24 of Set 4 | fortuna
# Processing Record 25 of Set 4 | ipira
# Processing Record 26 of Set 4 | constitucion
# Processing Record 27 of Set 4 | kruisfontein
# Processing Record 28 of Set 4 | sambava
# Processing Record 29 of Set 4 | narrabri
# Processing Record 30 of Set 4 | sabha
# Processing Record 31 of Set 4 | bonthe
# Processing Record 32 of Set 4 | beloha
# Processing Record 33 of Set 4 | gorontalo
# Processing Record 34 of Set 4 | krasnoye
# Processing Record 35 of Set 4 | leiyang
# Processing Record 36 of Set 4 | san cristobal
# City not found. Skipping...
# Processing Record 37 of Set 4 | marawi
# Processing Record 38 of Set 4 | nuuk
# Processing Record 39 of Set 4 | iracoubo
# Processing Record 40 of Set 4 | zhigansk
# Processing Record 41 of Set 4 | kupang
# Processing Record 42 of Set 4 | gladstone
# Processing Record 43 of Set 4 | praia da vitoria
# Processing Record 44 of Set 4 | havre-saint-pierre
# Processing Record 45 of Set 4 | hartford
# Processing Record 46 of Set 4 | bilibino
# Processing Record 47 of Set 4 | nastola
# Processing Record 48 of Set 4 | gweru
# Processing Record 49 of Set 4 | east london
# Processing Record 50 of Set 4 | sitka
# Processing Record 0 of Set 5 | macusani
# Processing Record 1 of Set 5 | saint-georges
# Processing Record 2 of Set 5 | pochutla
# Processing Record 3 of Set 5 | torbay
# Processing Record 4 of Set 5 | raudeberg
# Processing Record 5 of Set 5 | tasiilaq
# Processing Record 6 of Set 5 | ojinaga
# City not found. Skipping...
# Processing Record 7 of Set 5 | pevek
# Processing Record 8 of Set 5 | castro
# Processing Record 9 of Set 5 | airai
# Processing Record 10 of Set 5 | reconquista
# Processing Record 11 of Set 5 | nome
# Processing Record 12 of Set 5 | katherine
# Processing Record 13 of Set 5 | kysyl-syr
# Processing Record 14 of Set 5 | farrukhnagar
# Processing Record 15 of Set 5 | saint george
# Processing Record 16 of Set 5 | sibu
# Processing Record 17 of Set 5 | ponta do sol
# Processing Record 18 of Set 5 | ulan-ude
# Processing Record 19 of Set 5 | mount isa
# Processing Record 20 of Set 5 | wewak
# Processing Record 21 of Set 5 | barhi
# City not found. Skipping...
# Processing Record 22 of Set 5 | constantine
# Processing Record 23 of Set 5 | malakal
# Processing Record 24 of Set 5 | dingle
# City not found. Skipping...
# Processing Record 25 of Set 5 | san javier
# Processing Record 26 of Set 5 | bauchi
# Processing Record 27 of Set 5 | sal rei
# Processing Record 28 of Set 5 | syracuse
# Processing Record 29 of Set 5 | yar-sale
# Processing Record 30 of Set 5 | san felipe
# Processing Record 31 of Set 5 | novyy urengoy
# Processing Record 32 of Set 5 | mindelo
# City not found. Skipping...
# Processing Record 33 of Set 5 | bhor
# Processing Record 34 of Set 5 | port hardy
# City not found. Skipping...
# Processing Record 35 of Set 5 | tyubuk
# Processing Record 36 of Set 5 | berkeley heights
# Processing Record 37 of Set 5 | blackwater
# Processing Record 38 of Set 5 | kurumkan
# Processing Record 39 of Set 5 | oranjemund
# Processing Record 40 of Set 5 | aklavik
# City not found. Skipping...
# Processing Record 41 of Set 5 | sukhumi
# Processing Record 42 of Set 5 | omsukchan
# Processing Record 43 of Set 5 | sao joao da barra
# Processing Record 44 of Set 5 | namatanai
# Processing Record 45 of Set 5 | ostrovnoy
# Processing Record 46 of Set 5 | viedma
# Processing Record 47 of Set 5 | mogadishu
# Processing Record 48 of Set 5 | olafsvik
# Processing Record 49 of Set 5 | kavaratti
# Processing Record 50 of Set 5 | nemuro
# Processing Record 0 of Set 6 | muli
# Processing Record 1 of Set 6 | anadyr
# Processing Record 2 of Set 6 | ndele
# Processing Record 3 of Set 6 | durazno
# Processing Record 4 of Set 6 | kijang
# Processing Record 5 of Set 6 | saint-joseph
# Processing Record 6 of Set 6 | rincon
# City not found. Skipping...
# Processing Record 7 of Set 6 | korem
# Processing Record 8 of Set 6 | chernyshevskiy
# Processing Record 9 of Set 6 | strezhevoy
# Processing Record 10 of Set 6 | kandi
# Processing Record 11 of Set 6 | sobolevo
# Processing Record 12 of Set 6 | labuhan
# Processing Record 13 of Set 6 | jaguariaiva
# Processing Record 14 of Set 6 | bambous virieux
# Processing Record 15 of Set 6 | kangaatsiaq
# Processing Record 16 of Set 6 | evensk
# Processing Record 17 of Set 6 | filadelfia
# Processing Record 18 of Set 6 | maracaju
# Processing Record 19 of Set 6 | narsaq
# Processing Record 20 of Set 6 | ocos
# Processing Record 21 of Set 6 | hofn
# Processing Record 22 of Set 6 | bugko
# Processing Record 23 of Set 6 | polunochnoye
# Processing Record 24 of Set 6 | beringovskiy
# Processing Record 25 of Set 6 | fayaoue
# Processing Record 26 of Set 6 | bayan
# City not found. Skipping...
# Processing Record 27 of Set 6 | caconda
# City not found. Skipping...
# Processing Record 28 of Set 6 | halifax
# Processing Record 29 of Set 6 | kiama
# Processing Record 30 of Set 6 | naze
# Processing Record 31 of Set 6 | melito di porto salvo
# Processing Record 32 of Set 6 | faanui
# City not found. Skipping...
# Processing Record 33 of Set 6 | jardim
# Processing Record 34 of Set 6 | santa maria
# Processing Record 35 of Set 6 | la asuncion
# Processing Record 36 of Set 6 | lorengau
# Processing Record 37 of Set 6 | aksarka
# Processing Record 38 of Set 6 | ranfurly
# Processing Record 39 of Set 6 | bugac
# Processing Record 40 of Set 6 | kaniama
# Processing Record 41 of Set 6 | pangnirtung
# Processing Record 42 of Set 6 | olds
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 6 | vila velha
# Processing Record 44 of Set 6 | krasnoobsk
# Processing Record 45 of Set 6 | madhyamgram
# Processing Record 46 of Set 6 | esso
# Processing Record 47 of Set 6 | arawa
# City not found. Skipping...
# Processing Record 48 of Set 6 | launceston
# Processing Record 49 of Set 6 | mende
# Processing Record 50 of Set 6 | mareeba
# Processing Record 0 of Set 7 | olavarria
# Processing Record 1 of Set 7 | tura
# Processing Record 2 of Set 7 | huangchuan
# Processing Record 3 of Set 7 | xai-xai
# Processing Record 4 of Set 7 | arkansas city
# City not found. Skipping...
# Processing Record 5 of Set 7 | necochea
# Processing Record 6 of Set 7 | bara
# Processing Record 7 of Set 7 | bilma
# Processing Record 8 of Set 7 | beyneu
# Processing Record 9 of Set 7 | shelburne
# Processing Record 10 of Set 7 | kirensk
# Processing Record 11 of Set 7 | opuwo
# Processing Record 12 of Set 7 | gat
# Processing Record 13 of Set 7 | duobao
# City not found. Skipping...
# Processing Record 14 of Set 7 | chokurdakh
# Processing Record 15 of Set 7 | port elizabeth
# Processing Record 16 of Set 7 | mehamn
# Processing Record 17 of Set 7 | kahului
# Processing Record 18 of Set 7 | karratha
# Processing Record 19 of Set 7 | bath
# Processing Record 20 of Set 7 | madang
# Processing Record 21 of Set 7 | pitanga
# Processing Record 22 of Set 7 | tubuala
# Processing Record 23 of Set 7 | vestmanna
# Processing Record 24 of Set 7 | vanimo
# City not found. Skipping...
# Processing Record 25 of Set 7 | pisco
# Processing Record 26 of Set 7 | yerofey pavlovich
# Processing Record 27 of Set 7 | ifo
# Processing Record 28 of Set 7 | pafos
# Processing Record 29 of Set 7 | codrington
# Processing Record 30 of Set 7 | komarichi
# Processing Record 31 of Set 7 | riyadh
# Processing Record 32 of Set 7 | taoudenni
# Processing Record 33 of Set 7 | fukue
# Processing Record 34 of Set 7 | pionerskiy
# Processing Record 35 of Set 7 | la ciotat
# Processing Record 36 of Set 7 | north bend
# Processing Record 37 of Set 7 | muscat
# City not found. Skipping...
# Processing Record 38 of Set 7 | egvekinot
# Processing Record 39 of Set 7 | grand gaube
# Processing Record 40 of Set 7 | penon blanco
# Processing Record 41 of Set 7 | khuzdar
# Processing Record 42 of Set 7 | ahipara
# Processing Record 43 of Set 7 | requena
# Processing Record 44 of Set 7 | pontianak
# Processing Record 45 of Set 7 | port hedland
# Processing Record 46 of Set 7 | guarapari
# Processing Record 47 of Set 7 | caravelas
# Processing Record 48 of Set 7 | toguchin
# Processing Record 49 of Set 7 | lata
# Processing Record 50 of Set 7 | quchan
# Processing Record 0 of Set 8 | neuquen
# City not found. Skipping...
# Processing Record 1 of Set 8 | oktyabrskiy
# Processing Record 2 of Set 8 | catamarca
# Processing Record 3 of Set 8 | iztapa
# Processing Record 4 of Set 8 | sucha beskidzka
# Processing Record 5 of Set 8 | saint anthony
# Processing Record 6 of Set 8 | brora
# Processing Record 7 of Set 8 | atasu
# Processing Record 8 of Set 8 | jumla
# City not found. Skipping...
# Processing Record 9 of Set 8 | pasni
# Processing Record 10 of Set 8 | medveda
# Processing Record 11 of Set 8 | margate
# Processing Record 12 of Set 8 | usinsk
# Processing Record 13 of Set 8 | qasigiannguit
# Processing Record 14 of Set 8 | camocim
# Processing Record 15 of Set 8 | monster
# Processing Record 16 of Set 8 | rio gallegos
# Processing Record 17 of Set 8 | laranjeiras do sul
# Processing Record 18 of Set 8 | clyde river
# Processing Record 19 of Set 8 | batie
# Processing Record 20 of Set 8 | bol
# Processing Record 21 of Set 8 | serebryansk
# Processing Record 22 of Set 8 | paita
# City not found. Skipping...
# Processing Record 23 of Set 8 | marsh harbour
# Processing Record 24 of Set 8 | kalaleh
# Processing Record 25 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 8 | olinda
# Processing Record 27 of Set 8 | henties bay
# Processing Record 28 of Set 8 | visnes
# City not found. Skipping...
# Processing Record 29 of Set 8 | ankang
# Processing Record 30 of Set 8 | zunil
# Processing Record 31 of Set 8 | gawler
# Processing Record 32 of Set 8 | patitirion
# Processing Record 33 of Set 8 | pangai
# City not found. Skipping...
# Processing Record 34 of Set 8 | kaeo
# Processing Record 35 of Set 8 | aubenas
# Processing Record 36 of Set 8 | krasnyy chikoy
# Processing Record 37 of Set 8 | vao
# Processing Record 38 of Set 8 | flinders
# Processing Record 39 of Set 8 | buraydah
# Processing Record 40 of Set 8 | ambon
# City not found. Skipping...
# Processing Record 41 of Set 8 | dolores
# Processing Record 42 of Set 8 | verkhnevilyuysk
# Processing Record 43 of Set 8 | peace river
# Processing Record 44 of Set 8 | killybegs
# Processing Record 45 of Set 8 | qui nhon
# City not found. Skipping...
# Processing Record 46 of Set 8 | ostersund
# Processing Record 47 of Set 8 | kanye
# Processing Record 48 of Set 8 | ekangala
# City not found. Skipping...
# Processing Record 49 of Set 8 | clarence town
# Processing Record 50 of Set 8 | nauta
# Processing Record 0 of Set 9 | masasi
# Processing Record 1 of Set 9 | tual
# Processing Record 2 of Set 9 | alta floresta
# Processing Record 3 of Set 9 | tolstoy-yurt
# Processing Record 4 of Set 9 | sorland
# Processing Record 5 of Set 9 | caibarien
# Processing Record 6 of Set 9 | peleduy
# Processing Record 7 of Set 9 | biu
# Processing Record 8 of Set 9 | shimoda
# Processing Record 9 of Set 9 | mangrol
# Processing Record 10 of Set 9 | bocaiuva
# Processing Record 11 of Set 9 | gondar
# Processing Record 12 of Set 9 | kargil
# Processing Record 13 of Set 9 | cherskiy
# Processing Record 14 of Set 9 | zacualtipan
# Processing Record 15 of Set 9 | samagaltay
# Processing Record 16 of Set 9 | krasyliv
# Processing Record 17 of Set 9 | burnie
# Processing Record 18 of Set 9 | amfissa
# Processing Record 19 of Set 9 | avera
# Processing Record 20 of Set 9 | padang
# Processing Record 21 of Set 9 | roald
# Processing Record 22 of Set 9 | cedar city
# Processing Record 23 of Set 9 | mastung
# Processing Record 24 of Set 9 | emilio carranza
# Processing Record 25 of Set 9 | bathurst
# Processing Record 26 of Set 9 | qujing
# City not found. Skipping...
# Processing Record 27 of Set 9 | groningen
# Processing Record 28 of Set 9 | rio grande
# Processing Record 29 of Set 9 | quixeramobim
# Processing Record 30 of Set 9 | surt
# Processing Record 31 of Set 9 | kota belud
# Processing Record 32 of Set 9 | miles city
# Processing Record 33 of Set 9 | kolokani
# Processing Record 34 of Set 9 | burhaniye
# Processing Record 35 of Set 9 | athabasca
# Processing Record 36 of Set 9 | porto novo
# Processing Record 37 of Set 9 | kilimatinde
# Processing Record 38 of Set 9 | finnsnes
# Processing Record 39 of Set 9 | sayyan
# Processing Record 40 of Set 9 | cooma
# Processing Record 41 of Set 9 | sao francisco
# Processing Record 42 of Set 9 | saint-medard-en-jalles
# Processing Record 43 of Set 9 | kabinda
# Processing Record 44 of Set 9 | penha
# Processing Record 45 of Set 9 | vemalwada
# Processing Record 46 of Set 9 | ivankiv
# Processing Record 47 of Set 9 | deputatskiy
# Processing Record 48 of Set 9 | elk river
# Processing Record 49 of Set 9 | gobabis
# Processing Record 50 of Set 9 | de-kastri
# Processing Record 0 of Set 10 | borazjan
# City not found. Skipping...
# Processing Record 1 of Set 10 | asfi
# City not found. Skipping...
# Processing Record 2 of Set 10 | charters towers
# Processing Record 3 of Set 10 | whitehorse
# Processing Record 4 of Set 10 | santa rosalia
# Processing Record 5 of Set 10 | inirida
# Processing Record 6 of Set 10 | massaguet
# City not found. Skipping...
# Processing Record 7 of Set 10 | lafia
# Processing Record 8 of Set 10 | saint-pierre
# Processing Record 9 of Set 10 | kirkwall
# Processing Record 10 of Set 10 | snyder
# Processing Record 11 of Set 10 | sayat
# Processing Record 12 of Set 10 | hays
# Processing Record 13 of Set 10 | warri
# Processing Record 14 of Set 10 | sompeta
# Processing Record 15 of Set 10 | bourail
# Processing Record 16 of Set 10 | grand-santi
# Processing Record 17 of Set 10 | slupsk
# Processing Record 18 of Set 10 | gazli
# Processing Record 19 of Set 10 | pemba
# Processing Record 20 of Set 10 | teya
# Processing Record 21 of Set 10 | prozor
# Processing Record 22 of Set 10 | ilulissat
# Processing Record 23 of Set 10 | tezu
# Processing Record 24 of Set 10 | bay roberts
# Processing Record 25 of Set 10 | vestmannaeyjar
# Processing Record 26 of Set 10 | anupgarh
# Processing Record 27 of Set 10 | opportunity
# Processing Record 28 of Set 10 | paka
# Processing Record 29 of Set 10 | kargopol
# Processing Record 30 of Set 10 | nicoya
# Processing Record 31 of Set 10 | poum
# Processing Record 32 of Set 10 | morehead
# Processing Record 33 of Set 10 | chumikan
# Processing Record 34 of Set 10 | alyangula
# Processing Record 35 of Set 10 | haines junction
# Processing Record 36 of Set 10 | kununurra
# Processing Record 37 of Set 10 | eureka
# Processing Record 38 of Set 10 | rutul
# Processing Record 39 of Set 10 | nsanje
# Processing Record 40 of Set 10 | altay
# Processing Record 41 of Set 10 | grindavik
# Processing Record 42 of Set 10 | porto santo
# City not found. Skipping...
# Processing Record 43 of Set 10 | luanda
# Processing Record 44 of Set 10 | moron
# Processing Record 45 of Set 10 | guanica
# Processing Record 46 of Set 10 | medea
# City not found. Skipping...
# Processing Record 47 of Set 10 | berlevag
# Processing Record 48 of Set 10 | cuamba
# Processing Record 49 of Set 10 | fernie
# Processing Record 50 of Set 10 | shingu
# Processing Record 0 of Set 11 | port macquarie
# Processing Record 1 of Set 11 | wamba
# Processing Record 2 of Set 11 | rawson
# Processing Record 3 of Set 11 | kontagora
# Processing Record 4 of Set 11 | orange cove
# Processing Record 5 of Set 11 | hamilton
# Processing Record 6 of Set 11 | faya
# Processing Record 7 of Set 11 | barabinsk
# Processing Record 8 of Set 11 | omboue
# Processing Record 9 of Set 11 | lazdijai
# Processing Record 10 of Set 11 | chinhoyi
# Processing Record 11 of Set 11 | chabahar
# Processing Record 12 of Set 11 | sycow
# Processing Record 13 of Set 11 | kabalo
# Processing Record 14 of Set 11 | pershotravneve
# Processing Record 15 of Set 11 | manoel urbano
# Processing Record 16 of Set 11 | hanzhong
# Processing Record 17 of Set 11 | qiyang
# Processing Record 18 of Set 11 | kviteseid
# Processing Record 19 of Set 11 | sharkan
# Processing Record 20 of Set 11 | vila
# Processing Record 21 of Set 11 | ust-maya
# Processing Record 22 of Set 11 | arica
# Processing Record 23 of Set 11 | high level
# City not found. Skipping...
# Processing Record 24 of Set 11 | manakara
# Processing Record 25 of Set 11 | itaituba
# Processing Record 26 of Set 11 | batagay
# Processing Record 27 of Set 11 | lasa
# City not found. Skipping...
# Processing Record 28 of Set 11 | risor
# Processing Record 29 of Set 11 | haifa
# Processing Record 30 of Set 11 | claremore
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
 #Create a dataframe using information from data retrieval
weather_data = pd.DataFrame({
    "City" : city_list,
    "Lat" : lats_list,
    "Lng" : lngs_list,
    "Max Temp" : temp_max_list,
    "Humidity" : humidity_list,
    "Clouds" : cloud_list,
    "Wind Speed" : wind_speed_list,
    "Country" : country_list,
    "Date" : date_list    
})

#Save weather data to a cities csv file
weather_data.to_csv("../output_data/cities.csv", index=False)

#Display dataframe
weather_data.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Clouds  Wind Speed  \
# 0  New Norfolk -42.7826  147.0587     53.65        87     100        1.03
# 1     Bengkulu  -3.8004  102.2655     74.93        88     100        3.02
# 2  Kualakapuas  -3.0091  114.3876     75.36        98      98        0.83
# 3  Yellowknife  62.4560 -114.3525     45.41        68      40        1.01
# 4    Tuatapere -46.1333  167.6833     60.71        59     100        1.14
#
#   Country        Date
# 0      AU  1634939605
# 1      ID  1634939456
# 2      ID  1634939606
# 3      CA  1634939606
# 4      NZ  1634939607

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#check if there are any cities with Humidity >100% 
weather_data["Humidity"].describe()
# Out:
# count    540.000000
# mean      72.627778
# std       18.635165
# min       14.000000
# 25%       64.000000
# 50%       76.000000
# 75%       86.000000
# max      100.000000
# Name: Humidity, dtype: float64

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_101 = weather_data[(weather_data["Humidity"] > 100)].index
humidity_101
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

clean_city_data = weather_data.drop(humidity_101, inplace=False)
clean_city_data.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Clouds  Wind Speed  \
# 0  New Norfolk -42.7826  147.0587     53.65        87     100        1.03
# 1     Bengkulu  -3.8004  102.2655     74.93        88     100        3.02
# 2  Kualakapuas  -3.0091  114.3876     75.36        98      98        0.83
# 3  Yellowknife  62.4560 -114.3525     45.41        68      40        1.01
# 4    Tuatapere -46.1333  167.6833     60.71        59     100        1.14
#
#   Country        Date
# 0      AU  1634939605
# 1      ID  1634939456
# 2      ID  1634939606
# 3      CA  1634939606
# 4      NZ  1634939607

# %%
# Export the filtered city data into a csv
clean_city_data.to_csv("../output_data/clean_city_data.csv", index_label="City_ID")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
date_now = datetime.date(datetime.now())

# Create a scatter plot for latitude vs max temperature.
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Max Temp"]

fig1, ax1 = plt.subplots(figsize=(7,4))
plt.scatter(x_values, y_values, edgecolor="black", linewidth=1, marker="o", alpha=0.8)
plt.title(f"City Latitude vs Max Temperature {date_now}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

# Save the figure
plt.savefig("../output_data/latitude_vs_max_temp.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Humidity"]

fig1, ax1 = plt.subplots(figsize=(7, 4))
plt.scatter(x_values, y_values, edgecolor="black", linewidth=1, marker="o", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity {date_now}")
plt.grid()

# Save the figure
plt.savefig("../output_data/latitude_vs_humidity.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot for latitude vs cloudiness.
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Clouds"]

fig1, ax1 = plt.subplots(figsize=(7,4))
markersize=12
plt.scatter(x_values, y_values, edgecolor="black", linewidth=1, marker="o", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness {date_now}")
plt.grid()

# Save the figure
plt.savefig("../output_data/latitude_vs_cloudiness.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot for latitude vs wind speed.
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Wind Speed"]

fig1, ax1 = plt.subplots(figsize=(7,4))
markersize=12
plt.scatter(x_values, y_values, edgecolor="black", linewidth=1, marker="o", alpha=0.8)

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed {date_now}")
plt.grid()

# Save the figure
plt.savefig("../output_data/latitude_vs_wind_speed.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots for remaining activities
def plot_linear_regression(x_values, y_values, x_label, y_label, hemisphere, text_coordinates, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
    # Generate plots     
    fig1, ax1 = plt.subplots(figsize=(7,4))
    plt.scatter(x_values, y_values, edgecolor="black", linewidth=1, marker="o", alpha=0.8)
    plt.plot(x_values,regress_values,"r-")
    date_now = datetime.date(datetime.now())
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label} {date_now}",fontsize = 15)
    plt.xlabel(x_label,fontsize=14)
    plt.ylabel(y_label,fontsize=14)
    if ylim is not None:
        plt.ylim(0, ylim)
    plt.annotate(line_eq, text_coordinates, fontsize=20, color="red")
    
    # Print r square value
    print(f"The r-squared is: {rvalue**2}")
   # correlation = linregress.pearsonr(x_values, y_values)
   # print(f"The correlation between both factors is {round(correlation[0],2)}")

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_weather_df = clean_city_data.loc[clean_city_data["Lat"] >= 0]
southern_hemi_weather_df = clean_city_data.loc[clean_city_data["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs max temp (northern hemisphere)
x_values = northern_hemi_weather_df["Lat"]
y_values = northern_hemi_weather_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp (F)", "Northern", (10, 10))

# Save the figure
plt.savefig("../output_data/northern_hem_linear_lat_vs_max_temp.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.7253170602821186

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemi_weather_df["Lat"]
y_values = southern_hemi_weather_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp (F)", "Southern", (-52, 75))

# Save the figure
plt.savefig("../output_data/southern_hem_linear_lat_vs_max_temp.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.5133547949742939

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humditiy (northern hemisphere)
x_values = northern_hemi_weather_df['Lat']
y_values = northern_hemi_weather_df['Humidity']
plot_linear_regression(x_values, y_values, "Latitude", "Humidity (%)", "Northern",(50,50))
plt.savefig("../output_data/northern_hem_linear_lat_vs_humidity.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.02734910537182271

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humditiy (southern hemisphere)
x_values = southern_hemi_weather_df['Lat']
y_values = southern_hemi_weather_df['Humidity']
plot_linear_regression(x_values, y_values, "Latitude", "Humidity (%)", "Southern",(50, 50), 100)
plt.savefig("../output_data/southern_hem_linear_lat_vs_humudity.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.02799099171180299

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (northern hemisphere)
x_values = northern_hemi_weather_df['Lat']
y_values = northern_hemi_weather_df['Clouds']
plot_linear_regression(x_values, y_values, "Latitude", "Cloudiness (%)", "Northern", (20, 60))

plt.savefig("../output_data/northern_hem_linear_lat_vs_cloudiness.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.04820794766716179

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemi_weather_df['Lat']
y_values = southern_hemi_weather_df['Clouds']
plot_linear_regression(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))
plt.savefig("../output_data/southern_hem_linear_lat_vs_cloudiness.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.021532374746338543

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed(northern hemisphere)
x_values = northern_hemi_weather_df['Lat']
y_values = northern_hemi_weather_df['Wind Speed']
plot_linear_regression(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))
plt.savefig("../output_data/northern_hem_linear_lat_vs_wind_speed.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.037849669342714436

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed (southern hemisphere)
x_values = southern_hemi_weather_df['Lat']
y_values = southern_hemi_weather_df['Wind Speed']
plot_linear_regression(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(-40, 25), ylim=40)
plt.savefig("../output_data/southern_hem_linear_lat_vs_wind_speed.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.04614927188059143
